# %% [markdown]
# # Data Science Internship - LetsGrowMore
# # Kamal Subedi

# %% [markdown]
# #### 2nd Task  - Image to Pencil Sketch
# #### Reference: https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %%
# Importing the necessary libraries

# %%
from PIL import Image
from IPython.display import display
import cv2

# %%
# Loading the image

# %%
img = cv2.imread('img.jpg', 1)
img = cv2.resize(img, (640, 400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=640x400 at 0x17CF84FDA00>

# %%
# Converting image to grey scale

# %%
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(img_grey))
# Out:
# <PIL.Image.Image image mode=L size=640x400 at 0x17CF84FDA90>

# %%
# Inverting the image

# %%
img_inv = cv2.bitwise_not(img_grey)
display(Image.fromarray(img_inv))
# Out:
# <PIL.Image.Image image mode=L size=640x400 at 0x17CF85173D0>

# %%
# Smoothing the image

# %%
img_smooth = cv2.GaussianBlur(img_inv, (5, 5), 0, 0)
display(Image.fromarray(img_smooth))
# Out:
# <PIL.Image.Image image mode=L size=640x400 at 0x17CF8517610>

# %%
# Inverting the image to get final sketch

# %%
def dodge(img_grey, img_smooth):
  img_smooth_inv = 255 - img_smooth
  return cv2.divide(img_grey, img_smooth_inv, scale=256.0)

# %%
img_final = dodge(img_grey, img_smooth)
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=L size=640x400 at 0x17CF84FDBE0>

# %%
# Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=RGB size=640x400 at 0x17CF6DF9CD0>
# <PIL.Image.Image image mode=L size=640x400 at 0x17CF6E137C0>
